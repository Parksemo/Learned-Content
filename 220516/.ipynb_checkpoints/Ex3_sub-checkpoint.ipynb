# %%
import pandas as pd

# %%
t_d = pd.read_csv('data2.csv')
t_d.head(2)
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...

# %%
x_ck = t_d['review']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
c = WordCloud().generate(' '.join(t_d['review']))
plt.imshow(c)

# %%
t_d.shape
# Out:
# (25000, 3)

# %%
t_d.describe()
# Out:
#          sentiment
# count  25000.00000
# mean       0.50000
# std        0.50001
# min        0.00000
# 25%        0.00000
# 50%        0.50000
# 75%        1.00000
# max        1.00000

# %%
ck_df = t_d[['review', 'sentiment']]
ck_df.describe()
# Out:
#          sentiment
# count  25000.00000
# mean       0.50000
# std        0.50001
# min        0.00000
# 25%        0.00000
# 50%        0.50000
# 75%        1.00000
# max        1.00000

# %%
import seaborn as sns

# %%
sns.countplot(ck_df.sentiment)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
len(t_d['review'][0])
# Out:
# 2304

# %%
t_d['review'].apply(len) #각 문장의 길이
# Out:
# 0        2304
# 1         948
# 2        2451
# 3        2247
# 4        2233
#          ...
# 24995     582
# 24996     977
# 24997     643
# 24998    1143
# 24999     944
# Name: review, Length: 25000, dtype: int64

# %%
n_t = t_d['review'].apply(lambda x:len(x.split(' '))) # 각 문장에 있는 단어 개수
n_t
# Out:
# 0        433
# 1        158
# 2        378
# 3        379
# 4        367
#         ...
# 24995     95
# 24996    174
# 24997    127
# 24998    197
# 24999    184
# Name: review, Length: 25000, dtype: int64

# %%
plt.hist(n_t,50)
plt.yscale('log',nonposy = 'clip')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_27380/2690775549.py:2: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.yscale('log',nonposy = 'clip')

# %%
ck_df.isna().sum() #결측치 확인
# Out:
# review       0
# sentiment    0
# dtype: int64
