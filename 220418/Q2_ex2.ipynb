# %%
from wordcloud import WordCloud #워드클라우드모듈
import matplotlib.pyplot as plt #그래프모듈
from collections import Counter #횟수적용모듈
from konlpy.tag import Okt
import pandas as pd

# %%
df=pd.read_csv('ex2_data.csv',encoding='cp949')
df
# Out:
#                         제목                                                 내용  \
# 0          맛은 좋은데 양이 좀 적네요                                    맛은 좋은데 양이 좀 적네요
# 1     청결고춧가루 고추잠자리 골드(보통맛)  잘 받았습니다.출타중이이어서 늦게 구매확정 후 상품평을 올리게 되었습니다.잘 먹겠습니다.
# 2                    꿀 고구마                                              꿀 고구마
# 3                    감사합니다                                     신선하다고 하네요감사합니다
# 4    울금이 피로회복에 절대강자! 구매했어요  울금은 피로회복에 절대강자!!피곤할때 울금을 물에 타서 마시면 피곤함이 없어져요.오...
# ..                     ...                                                ...
# 274      맛과 모양이 훌륭한 고구마!!!   모험한번 해보자 하는 맘으로 주문했는데  사진과 똑같은 모양에 쪄서 맛을보니 너무...
# 275                괴산 청결고추  올 김장에 쓸 꼭지달린 마른 통고추를 주문해서 받아보니 청결이란말을 왜 쓰는지 이유...
# 276                 잘 받았어요  절인배추 구입하러 들어왔다가 이벤트 상품이 있길래 구입해봤어요. 신랑 음용해봤는데 ...
# 277             풋사과즙 맛있어요~  풋사과가 항산화물질인 폴리페놀이 들어있다는것을 어렴풋이 알고있었는데 마침 반값행사한...
# 278                  넘 좋아요                                      맛있어서 두번째구매합니다
#
#          데이터기준일
# 0    2020-02-27
# 1    2020-02-27
# 2    2020-02-27
# 3    2020-02-27
# 4    2020-02-27
# ..          ...
# 274  2020-02-27
# 275  2020-02-27
# 276  2020-02-27
# 277  2020-02-27
# 278  2020-02-27
#
# [279 rows x 3 columns]

# %%
text=df['내용']
text
# Out:
# 0                                        맛은 좋은데 양이 좀 적네요
# 1      잘 받았습니다.출타중이이어서 늦게 구매확정 후 상품평을 올리게 되었습니다.잘 먹겠습니다.
# 2                                                  꿀 고구마
# 3                                         신선하다고 하네요감사합니다
# 4      울금은 피로회복에 절대강자!!피곤할때 울금을 물에 타서 마시면 피곤함이 없어져요.오...
#                              ...
# 274     모험한번 해보자 하는 맘으로 주문했는데  사진과 똑같은 모양에 쪄서 맛을보니 너무...
# 275    올 김장에 쓸 꼭지달린 마른 통고추를 주문해서 받아보니 청결이란말을 왜 쓰는지 이유...
# 276    절인배추 구입하러 들어왔다가 이벤트 상품이 있길래 구입해봤어요. 신랑 음용해봤는데 ...
# 277    풋사과가 항산화물질인 폴리페놀이 들어있다는것을 어렴풋이 알고있었는데 마침 반값행사한...
# 278                                        맛있어서 두번째구매합니다
# Name: 내용, Length: 279, dtype: object

# %%
ok_t=Okt()
data1=[]
for i in text:
    t=ok_t.nouns(i)
    data1.extend(t)
data1
# Out:
# ['맛',
#  '양',
#  '좀',
#  '출타',
#  '중이',
#  '구매',
#  '확정',
#  '후',
#  '상품',
#  '평',
#  '꿀',
#  '고구마',
#  '울금',
#  '피로',
#  '회복',
#  '절',
#  '대강',
#  '때',
#  '울금',
#  '물',
#  '만',
#  '다시',
#  '울금',
#  '구매',
#  '입안',
#  '혓바늘',
#  '때',
#  '양치',
#  '후',
#  '금가루',
#  '자고',
#  '혓바늘',
#  '것',
#  '배송',
#  '배송',
#  '배송',
#  '구매',
#  '한번',
#  '일시',
#  '문자',
#  '주시',
#  '얼릉',
#  '사기',
#  '이번',
#  '사과',
#  '깜짝',
#  '일시',
#  '얼릉',
#  '산후',
#  '박스',
#  '주문',
#  '아기',
#  '남편',
#  '박스',
#  '주문',
#  '남편',
#  '일',
#  '때',
#  '개',
#  '아기',
#  '주기도',
#  '아주',
#  '것',
#  '첨가',
#  '좀',
#  '쌉싸르',
#  '맛',
#  '찌꺼기',
#  '끝',
#  '뭐',
#  '거가',
#  '수입',
#  '귀리',
#  '이번',
#  '국산',
#  '괴산군',
#  '청',
#  '관리',
#  '운영',
#  '괴산',
#  '장터',
#  '알',
#  '구입',
#  '수입',
#  '맛',
#  '또',
#  '구매',
#  '아이',
#  '저염식',
#  '주문',
#  '절',
#  '김치',
#  '수',
#  '또',
#  '초록색',
#  '겉잎',
#  '김치',
#  '때',
#  '우거지',
#  '저장',
#  '수',
#  '괴산',
#  '옥수수',
#  '접',
#  '지도',
#  '년',
#  '것',
#  '옥수수',
#  '무척',
#  '냉동',
#  '옥수수',
#  '것',
#  '알',
#  '두번째',
#  '주문',
#  '도착',
#  '몇개',
#  '냉동',
#  '실',
#  '보관',
#  '때',
#  '마다',
#  '전자렌지',
#  '살짝',
#  '간식',
#  '것',
#  '도착',
#  '몇개',
#  '냉동',
#  '실',
#  '보관',
#  '때',
#  '마다',
#  '예정',
#  '옥수수',
#  '제철',
#  '기대',
#  '옥수수',
#  '날씨',
#  '걱정',
#  '아이스박스',
#  '포장',
#  '냉매',
#  '김장',
#  '철',
#  '절임',
#  '배추',
#  '도착',
#  '괴산',
#  '절임',
#  '배추',
#  '정말',
#  '올갱이',
#  '껍질',
#  '분리',
#  '시간',
#  '알맹이',
#  '사려',
#  '껍질',
#  '성분',
#  '생각',
#  '수원',
#  '액',
#  '결과',
#  '만족',
#  '된장',
#  '올갱이',
#  '살',
#  '맛',
#  '기분',
#  '간',
#  '건강',
#  '신랑',
#  '또',
#  '올갱이',
#  '일단',
#  '부담',
#  '간',
#  '음식',
#  '차',
#  '올갱이',
#  '정말',
#  '이산',
#  '액',
#  '국',
#  '또',
#  '좀',
#  '살로',
#  '부추',
#  '전',
#  '거도',
#  '나이',
#  '지그',
#  '어르신',
#  '주문',
#  '부탁',
#  '거',
#  '여기저기',
#  '곳',
#  '주문',
#  '효과',
#  '행사',
#  '때',
#  '구매',
#  '맛',
#  '전자',
#  '렌즈',
#  '도',
#  '아이',
#  '먹기',
#  '살짝',
#  '아침',
#  '마자',
#  '찜통',
#  '찌',
#  '아이',
#  '수',
#  '정도',
#  '말',
#  '거리',
#  '또',
#  '행사',
#  '사고',
#  '맛',
#  '년전',
#  '괴산',
#  '올갱이',
#  '마을',
#  '이후',
#  '항상',
#  '보리',
#  '결명자',
#  '여기',
#  '정수기',
#  '물',
#  '보리',
#  '우려',
#  '농사',
#  '정말',
#  '감사',
#  '지인',
#  '소개',
#  '구매',
#  '매콤',
#  '자주',
#  '이용',
#  '무청',
#  '시래기',
#  '한번',
#  '양으로',
#  '포장',
#  '알',
#  '때',
#  '블루베리',
#  '향',
#  '마트',
#  '사',
#  '블루베리',
#  '것',
#  '여명',
#  '농원',
#  '블루베리',
#  '무엇',
#  '맘',
#  '듭니',
#  '부모님',
#  '도',
#  '아침',
#  '저녁',
#  '해',
#  '의사',
#  '농작물',
#  '감사',
#  '봉지',
#  '시래기',
#  '국',
#  '처음',
#  '좀',
#  '계속',
#  '어제',
#  '온',
#  '감자',
#  '아침',
#  '감자',
#  '맛',
#  '반품',
#  '못',
#  '정말',
#  '최악',
#  '도착',
#  '선택',
#  '건데',
#  '내일',
#  '배송',
#  '좀',
#  '미리',
#  '연락',
#  '재료',
#  '준비',
#  '수',
#  '토요일',
#  '저녁',
#  '도착',
#  '배추',
#  '얼마나',
#  '절',
#  '물이',
#  '배추',
#  '뻘겋',
#  '아이스팩',
#  '상태',
#  '정말',
#  '말',
#  '배송',
#  '조회',
#  '감자',
#  '상태',
#  '처음',
#  '보고',
#  '또',
#  '우선',
#  '블루베리',
#  '알',
#  '맛',
#  '콤',
#  '밍밍',
#  '동네',
#  '블루베리',
#  '정말',
#  '살',
#  '살',
#  '우리',
#  '아이',
#  '간식',
#  '준',
#  '엄마',
#  '플레인',
#  '요거트',
#  '더',
#  '그냥',
#  '블루베리',
#  '김치',
#  '워낙',
#  '남편',
#  '때문',
#  '김치',
#  '똑',
#  '기전',
#  '김치',
#  '절임',
#  '배수',
#  '주문',
#  '김치',
#  '힘',
#  '도움',
#  '절임',
#  '배추',
#  '김장',
#  '철',
#  '주문',
#  '가을',
#  '배추',
#  '맛',
#  '데',
#  '건강',
#  '때',
#  '집안일',
#  '작년',
#  '남작',
#  '감자',
#  '구매',
#  '품질',
#  '맛',
#  '최상급',
#  '지인',
#  '소개',
#  '올해',
#  '기대',
#  '오직',
#  '여기',
#  '구입',
#  '위해',
#  '번',
#  '전화',
#  '구매',
#  '기대',
#  '달리',
#  '호미',
#  '캔',
#  '것',
#  '때',
#  '말',
#  '거림',
#  '남작',
#  '품종',
#  '전혀',
#  '미감',
#  '개',
#  '하자',
#  '선',
#  '해',
#  '남',
#  '슴',
#  '배송',
#  '포장',
#  '아주',
#  '감자',
#  '정말',
#  '인증서',
#  '포장',
#  '신경',
#  '보람',
#  '물건',
#  '확인',
#  '정말',
#  '먹기',
#  '반찬',
#  '해',
#  '읍니',
#  '농장',
#  '세번',
#  '구입',
#  '요',
#  '발송',
#  '문자',
#  '깜짝',
#  '무선',
#  '별',
#  '알',
#  '덜',
#  '것',
#  '수확',
#  '옥수수',
#  '일도',
#  '해주',
#  '정말',
#  '추가',
#  '주문',
#  '자루',
#  '포장',
#  '가격',
#  '무',
#  '번창',
#  '포장',
#  '상태',
#  '옥수수',
#  '크기',
#  '일정',
#  '한편',
#  '쫄깃',
#  '옥수수',
#  '친정',
#  '선물',
#  '쫄깃',
#  '옥수수',
#  '처음',
#  '친정',
#  '언니',
#  '박스',
#  '쫄깃',
#  '옥수수',
#  '특유',
#  '감칠맛',
#  '정말',
#  '언니',
#  '명',
#  '선물',
#  '포장',
#  '감칠맛',
#  '나',
#  '옥수수',
#  '진짜',
#  '흐믓했어',
#  '여름',
#  '옥수수',
#  '농사',
#  '고생',
#  '이용',
#  '후기',
#  '귀차니즘',
#  '정말',
#  '옥수수',
#  '앞',
#  '품질',
#  '옥수수',
#  '개',
#  '주변',
#  '모든',
#  '분',
#  '식구',
#  '개',
#  '더',
#  '주문',
#  '옥수수',
#  '몸',
#  '브로콜리',
#  '마트',
#  '낱개',
#  '장아찌',
#  '구입',
#  '주소',
#  '입력',
#  '불구',
#  '일이',
#  '엉터리',
#  '주소',
#  '잘못',
#  '배송',
#  '다음',
#  '날',
#  '다시',
#  '우여곡절',
#  '지역',
#  '농산물',
#  '시들시들',
#  '누렇',
#  '브로콜리',
#  '대학',
#  '옥수수',
#  '쫀득쫀득합니',
#  '쫀득합니',
#  '옥수수',
#  '크기',
#  '알맹이',
#  '쫀득',
#  '맛',
#  '요',
#  '옥수수',
#  '검색',
#  '괴산',
#  '장터',
#  '푸른',
#  '농장',
#  '예약',
#  '할인',
#  '반신',
#  '반',
#  '생각',
#  '주문',
#  '정말',
#  '사실',
#  '기대',
#  '번가',
#  '햇',
#  '찰옥수수',
#  '낭패',
#  '서리',
#  '알',
#  '도안',
#  '차고',
#  '작고',
#  '맛',
#  '개',
#  '완전',
#  '내년',
#  '앞',
#  '푸른',
#  '농장',
#  '어머니',
#  '보더',
#  '처음',
#  '옥수수',
#  '예약',
#  '구매',
#  '오늘',
#  '바로',
#  '예약',
#  '구매',
#  '구매',
#  '판매',
#  '농부',
#  '강원도',
#  '찰옥수수',
#  '안방',
#  '어제',
#  '저녁',
#  '발송',
#  '제품',
#  '오늘',
#  '바로',
#  '텃밭',
#  '바로',
#  '맛',
#  '날씨',
#  '앞',
#  '계속',
#  '의',
#  '쭈욱',
#  '읍니',
#  '감사',
#  '주문',
#  '옥수수',
#  '오늘',
#  '도착',
#  '맛',
#  '옥수수',
#  '반음',
#  '냉동',
#  '실로',
#  '반',
#  '식구',
#  '해',
#  '장연',
#  '옥수수',
#  '펜',
#  '계속',
#  '주문',
#  '해먹',
#  '거나',
#  '마트',
#  '처음',
#  '장연',
#  '우체국',
#  '해먹',
#  '땐',
#  '옥수수',
#  '맛',
#  '정도',
#  '이나',
#  '시기',
#  '주문',
#  '여름',
#  '이면',
#  '포대',
#  '이상은',
#  '주문',
#  '추천',
#  '어제',
#  '신경',
#  '선별',
#  '이',
#  '날씨',
#  '고생',
#  '정말',
#  '감사',
#  '맛',
#  '앞',
#  '쭈우욱',
#  '단골',
#  '날씨',
#  '건강',
#  '수고',
#  '품질',
#  '옥수수',
#  '감사',
#  '아침',
#  '제대로',
#  '식구',
#  '볼때',
#  '귀리',
#  '선',
#  '침',
#  '식사',
#  '대용',
#  '괴산',
#  '장터',
#  '감자',
#  '처음',
#  '주문',
#  '완전',
#  '대성공',
#  '우리',
#  '집',
#  '박스',
#  '친정',
#  '박스',
#  '시댁',
#  '박스',
#  '주문',
#  '어르신',
#  '지씨',
#  '농가',
#  '유기농',
#  '무',
#  '농약',
#  '농작물',
#  '옥수수',
#  '주문',
#  '괴산',
#  '장터',
#  '감자',
#  '처음',
#  '주문',
#  '완전',
#  '대성공',
#  '우리',
#  '집',
#  '박스',
#  '친정',
#  '박스',
#  '시댁',
#  '박스',
#  '주문',
#  '어르신',
#  '유기농',
#  '무',
#  '농약',
#  '옥수수',
#  '주문',
#  '무척',
#  '여름',
#  '옥수수',
#  '농사',
#  '수고',
#  '덕분',
#  '옥수수',
#  '수',
#  '다음',
#  '또',
#  '주문',
#  '여름',
#  '이면',
#  '옥수수',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '톡톡',
#  '맛',
#  '옥수수',
#  '비교',
#  '맛',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '정말',
#  '톡톡',
#  '맛',
#  '식구',
#  '모',
#  '하모니카',
#  '불면',
#  '옥수수',
#  '괴산',
#  '대학',
#  '옥수수',
#  '고산',
#  '대학',
#  '찰옥수수',
#  '최고',
#  '학생',
#  '옥수수',
#  '몇개',
#  '가지',
#  '후',
#  '이',
#  '옥수수',
#  '인연',
#  '학생',
#  '부모님',
#  '충',
#  '농',
#  '시즌',
#  '때',
#  '년',
#  '번',
#  '구입',
#  '수',
#  '전해',
#  '이후',
#  '매년',
#  '구입',
#  '중',
#  '미국',
#  '살',
#  '그',
#  '때',
#  '그',
#  '옥수수',
#  '귀국',
#  '후',
#  '집',
#  '앞',
#  '마트',
#  '대학',
#  '찰',
#  '판매',
#  '것',
#  '사서',
#  '입맛',
#  '바',
#  '옥수수',
#  '개',
#  '옥수수',
#  '품질',
#  '갯수',
#  '찰옥수수',
#  '개',
#  '구매',
#  '옥수수',
#  '알도',
#  '감칠맛',
#  '내년',
#  '의사',
#  '오늘',
#  '알도',
#  '쫀득쫀득',
#  '것',
#  '동생',
#  '선물',
#  '더',
#  '주문',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '옥수수',
#  '비교',
#  '알갱이',
#  '톡톡',
#  '번',
#  '부드러움',
#  '살이',
#  '괴산',
#  '찰옥수수',
#  '정말',
#  '맛',
#  '괴산',
#  '찰옥수수',
#  '정말',
#  '맛',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '맛',
#  '요',
#  '작년',
#  '올해',
#  '주문',
#  '괴산',
#  '찰옥수수',
#  '다른',
#  '건',
#  '가족',
#  '친척',
#  '두루',
#  '포장',
#  '옥수수',
#  '모두',
#  '칭찬',
#  '기분',
#  '월요일',
#  '주문',
#  '금요일',
#  '배송',
#  '완료',
#  '맛',
#  '옥수수',
#  '정성',
#  '스레',
#  '감사',
#  '인사',
#  '선물',
#  '용',
#  '좀더',
#  '주문',
#  '뭐',
#  '사진',
#  '표고',
#  '줄알',
#  '일반',
#  '마트',
#  '거',
#  '더군다나',
#  '날씨',
#  '스티로폼',
#  '박스',
#  '얼음',
#  '버섯',
#  '꽉',
#  '바람',
#  '냄새',
#  '몇개',
#  '주문',
#  '대학',
#  '찰옥수수',
#  '가족',
#  '쫀득',
#  '날씨',
#  '고생',
#  '다음',
#  '또',
#  '주문',
#  '배송',
#  '물품',
#  '옥수수',
#  '수확',
#  '일이',
#  '예정일',
#  '이상',
#  '지연',
#  '점도',
#  '실망',
#  '옥수수',
#  '상태',
#  '아주',
#  '상태',
#  '실망',
#  '부모님',
#  '개',
#  '주문',
#  '금방',
#  '주문',
#  '부모님',
#  '부탁',
#  '대신',
#  '주문',
#  '칭찬',
#  '하나',
#  '배송',
#  '알도',
#  '하나',
#  '배송',
#  '알도',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '살이',
#  '톡톡',
#  '괴산',
#  '찰옥수수',
#  '여름',
#  '이면',
#  '주문',
#  '정말',
#  '옥수수',
#  '최고',
#  '쫀득',
#  '번',
#  '모두',
#  '가족',
#  '지인',
#  '냉동',
#  '실',
#  '며칠',
#  '못',
#  '가요',
#  '여름',
#  '고생',
#  '또',
#  '주문',
#  '옥수수',
#  '맛',
#  '평가',
#  '남편',
#  '셰프',
#  '인양',
#  '맛',
#  '평가',
#  '남편',
#  '질색',
#  '처음',
#  '사본',
#  '대학',
#  '찰옥수수',
#  '평소',
#  '옥수수',
#  '신랑',
#  '앞',
#  '또',
#  '릴',
#  '신랑',
#  '왈',
#  '거',
#  '달짝',
#  '옥수수',
#  '삶',
#  '때',
#  '뭐',
#  '나',
#  '옥수수',
#  '신랑',
#  '표정',
#  '이제',
#  '대학',
#  '찰옥수수',
#  '덕분',
#  '옥수수',
#  '살',
#  '고민',
#  '안해',
#  '배송',
#  '유래',
#  '폭염',
#  '소비자',
#  '맛',
#  '옥수수',
#  '긊',
#  '나기',
#  '위해',
#  '수고',
#  '괴산',
#  '장터',
#  '직접',
#  '생산',
#  '현장',
#  '땀',
#  '경작',
#  '님',
#  '옥수수',
#  '옛날',
#  '옥수수',
#  ...]

# %%
data2=[i for i in data1 if len(i)>1]
data2
# Out:
# ['출타',
#  '중이',
#  '구매',
#  '확정',
#  '상품',
#  '고구마',
#  '울금',
#  '피로',
#  '회복',
#  '대강',
#  '울금',
#  '다시',
#  '울금',
#  '구매',
#  '입안',
#  '혓바늘',
#  '양치',
#  '금가루',
#  '자고',
#  '혓바늘',
#  '배송',
#  '배송',
#  '배송',
#  '구매',
#  '한번',
#  '일시',
#  '문자',
#  '주시',
#  '얼릉',
#  '사기',
#  '이번',
#  '사과',
#  '깜짝',
#  '일시',
#  '얼릉',
#  '산후',
#  '박스',
#  '주문',
#  '아기',
#  '남편',
#  '박스',
#  '주문',
#  '남편',
#  '아기',
#  '주기도',
#  '아주',
#  '첨가',
#  '쌉싸르',
#  '찌꺼기',
#  '거가',
#  '수입',
#  '귀리',
#  '이번',
#  '국산',
#  '괴산군',
#  '관리',
#  '운영',
#  '괴산',
#  '장터',
#  '구입',
#  '수입',
#  '구매',
#  '아이',
#  '저염식',
#  '주문',
#  '김치',
#  '초록색',
#  '겉잎',
#  '김치',
#  '우거지',
#  '저장',
#  '괴산',
#  '옥수수',
#  '지도',
#  '옥수수',
#  '무척',
#  '냉동',
#  '옥수수',
#  '두번째',
#  '주문',
#  '도착',
#  '몇개',
#  '냉동',
#  '보관',
#  '마다',
#  '전자렌지',
#  '살짝',
#  '간식',
#  '도착',
#  '몇개',
#  '냉동',
#  '보관',
#  '마다',
#  '예정',
#  '옥수수',
#  '제철',
#  '기대',
#  '옥수수',
#  '날씨',
#  '걱정',
#  '아이스박스',
#  '포장',
#  '냉매',
#  '김장',
#  '절임',
#  '배추',
#  '도착',
#  '괴산',
#  '절임',
#  '배추',
#  '정말',
#  '올갱이',
#  '껍질',
#  '분리',
#  '시간',
#  '알맹이',
#  '사려',
#  '껍질',
#  '성분',
#  '생각',
#  '수원',
#  '결과',
#  '만족',
#  '된장',
#  '올갱이',
#  '기분',
#  '건강',
#  '신랑',
#  '올갱이',
#  '일단',
#  '부담',
#  '음식',
#  '올갱이',
#  '정말',
#  '이산',
#  '살로',
#  '부추',
#  '거도',
#  '나이',
#  '지그',
#  '어르신',
#  '주문',
#  '부탁',
#  '여기저기',
#  '주문',
#  '효과',
#  '행사',
#  '구매',
#  '전자',
#  '렌즈',
#  '아이',
#  '먹기',
#  '살짝',
#  '아침',
#  '마자',
#  '찜통',
#  '아이',
#  '정도',
#  '거리',
#  '행사',
#  '사고',
#  '년전',
#  '괴산',
#  '올갱이',
#  '마을',
#  '이후',
#  '항상',
#  '보리',
#  '결명자',
#  '여기',
#  '정수기',
#  '보리',
#  '우려',
#  '농사',
#  '정말',
#  '감사',
#  '지인',
#  '소개',
#  '구매',
#  '매콤',
#  '자주',
#  '이용',
#  '무청',
#  '시래기',
#  '한번',
#  '양으로',
#  '포장',
#  '블루베리',
#  '마트',
#  '블루베리',
#  '여명',
#  '농원',
#  '블루베리',
#  '무엇',
#  '듭니',
#  '부모님',
#  '아침',
#  '저녁',
#  '의사',
#  '농작물',
#  '감사',
#  '봉지',
#  '시래기',
#  '처음',
#  '계속',
#  '어제',
#  '감자',
#  '아침',
#  '감자',
#  '반품',
#  '정말',
#  '최악',
#  '도착',
#  '선택',
#  '건데',
#  '내일',
#  '배송',
#  '미리',
#  '연락',
#  '재료',
#  '준비',
#  '토요일',
#  '저녁',
#  '도착',
#  '배추',
#  '얼마나',
#  '물이',
#  '배추',
#  '뻘겋',
#  '아이스팩',
#  '상태',
#  '정말',
#  '배송',
#  '조회',
#  '감자',
#  '상태',
#  '처음',
#  '보고',
#  '우선',
#  '블루베리',
#  '밍밍',
#  '동네',
#  '블루베리',
#  '정말',
#  '우리',
#  '아이',
#  '간식',
#  '엄마',
#  '플레인',
#  '요거트',
#  '그냥',
#  '블루베리',
#  '김치',
#  '워낙',
#  '남편',
#  '때문',
#  '김치',
#  '기전',
#  '김치',
#  '절임',
#  '배수',
#  '주문',
#  '김치',
#  '도움',
#  '절임',
#  '배추',
#  '김장',
#  '주문',
#  '가을',
#  '배추',
#  '건강',
#  '집안일',
#  '작년',
#  '남작',
#  '감자',
#  '구매',
#  '품질',
#  '최상급',
#  '지인',
#  '소개',
#  '올해',
#  '기대',
#  '오직',
#  '여기',
#  '구입',
#  '위해',
#  '전화',
#  '구매',
#  '기대',
#  '달리',
#  '호미',
#  '거림',
#  '남작',
#  '품종',
#  '전혀',
#  '미감',
#  '하자',
#  '배송',
#  '포장',
#  '아주',
#  '감자',
#  '정말',
#  '인증서',
#  '포장',
#  '신경',
#  '보람',
#  '물건',
#  '확인',
#  '정말',
#  '먹기',
#  '반찬',
#  '읍니',
#  '농장',
#  '세번',
#  '구입',
#  '발송',
#  '문자',
#  '깜짝',
#  '무선',
#  '수확',
#  '옥수수',
#  '일도',
#  '해주',
#  '정말',
#  '추가',
#  '주문',
#  '자루',
#  '포장',
#  '가격',
#  '번창',
#  '포장',
#  '상태',
#  '옥수수',
#  '크기',
#  '일정',
#  '한편',
#  '쫄깃',
#  '옥수수',
#  '친정',
#  '선물',
#  '쫄깃',
#  '옥수수',
#  '처음',
#  '친정',
#  '언니',
#  '박스',
#  '쫄깃',
#  '옥수수',
#  '특유',
#  '감칠맛',
#  '정말',
#  '언니',
#  '선물',
#  '포장',
#  '감칠맛',
#  '옥수수',
#  '진짜',
#  '흐믓했어',
#  '여름',
#  '옥수수',
#  '농사',
#  '고생',
#  '이용',
#  '후기',
#  '귀차니즘',
#  '정말',
#  '옥수수',
#  '품질',
#  '옥수수',
#  '주변',
#  '모든',
#  '식구',
#  '주문',
#  '옥수수',
#  '브로콜리',
#  '마트',
#  '낱개',
#  '장아찌',
#  '구입',
#  '주소',
#  '입력',
#  '불구',
#  '일이',
#  '엉터리',
#  '주소',
#  '잘못',
#  '배송',
#  '다음',
#  '다시',
#  '우여곡절',
#  '지역',
#  '농산물',
#  '시들시들',
#  '누렇',
#  '브로콜리',
#  '대학',
#  '옥수수',
#  '쫀득쫀득합니',
#  '쫀득합니',
#  '옥수수',
#  '크기',
#  '알맹이',
#  '쫀득',
#  '옥수수',
#  '검색',
#  '괴산',
#  '장터',
#  '푸른',
#  '농장',
#  '예약',
#  '할인',
#  '반신',
#  '생각',
#  '주문',
#  '정말',
#  '사실',
#  '기대',
#  '번가',
#  '찰옥수수',
#  '낭패',
#  '서리',
#  '도안',
#  '차고',
#  '작고',
#  '완전',
#  '내년',
#  '푸른',
#  '농장',
#  '어머니',
#  '보더',
#  '처음',
#  '옥수수',
#  '예약',
#  '구매',
#  '오늘',
#  '바로',
#  '예약',
#  '구매',
#  '구매',
#  '판매',
#  '농부',
#  '강원도',
#  '찰옥수수',
#  '안방',
#  '어제',
#  '저녁',
#  '발송',
#  '제품',
#  '오늘',
#  '바로',
#  '텃밭',
#  '바로',
#  '날씨',
#  '계속',
#  '쭈욱',
#  '읍니',
#  '감사',
#  '주문',
#  '옥수수',
#  '오늘',
#  '도착',
#  '옥수수',
#  '반음',
#  '냉동',
#  '실로',
#  '식구',
#  '장연',
#  '옥수수',
#  '계속',
#  '주문',
#  '해먹',
#  '거나',
#  '마트',
#  '처음',
#  '장연',
#  '우체국',
#  '해먹',
#  '옥수수',
#  '정도',
#  '이나',
#  '시기',
#  '주문',
#  '여름',
#  '이면',
#  '포대',
#  '이상은',
#  '주문',
#  '추천',
#  '어제',
#  '신경',
#  '선별',
#  '날씨',
#  '고생',
#  '정말',
#  '감사',
#  '쭈우욱',
#  '단골',
#  '날씨',
#  '건강',
#  '수고',
#  '품질',
#  '옥수수',
#  '감사',
#  '아침',
#  '제대로',
#  '식구',
#  '볼때',
#  '귀리',
#  '식사',
#  '대용',
#  '괴산',
#  '장터',
#  '감자',
#  '처음',
#  '주문',
#  '완전',
#  '대성공',
#  '우리',
#  '박스',
#  '친정',
#  '박스',
#  '시댁',
#  '박스',
#  '주문',
#  '어르신',
#  '지씨',
#  '농가',
#  '유기농',
#  '농약',
#  '농작물',
#  '옥수수',
#  '주문',
#  '괴산',
#  '장터',
#  '감자',
#  '처음',
#  '주문',
#  '완전',
#  '대성공',
#  '우리',
#  '박스',
#  '친정',
#  '박스',
#  '시댁',
#  '박스',
#  '주문',
#  '어르신',
#  '유기농',
#  '농약',
#  '옥수수',
#  '주문',
#  '무척',
#  '여름',
#  '옥수수',
#  '농사',
#  '수고',
#  '덕분',
#  '옥수수',
#  '다음',
#  '주문',
#  '여름',
#  '이면',
#  '옥수수',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '톡톡',
#  '옥수수',
#  '비교',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '정말',
#  '톡톡',
#  '식구',
#  '하모니카',
#  '불면',
#  '옥수수',
#  '괴산',
#  '대학',
#  '옥수수',
#  '고산',
#  '대학',
#  '찰옥수수',
#  '최고',
#  '학생',
#  '옥수수',
#  '몇개',
#  '가지',
#  '옥수수',
#  '인연',
#  '학생',
#  '부모님',
#  '시즌',
#  '구입',
#  '전해',
#  '이후',
#  '매년',
#  '구입',
#  '미국',
#  '옥수수',
#  '귀국',
#  '마트',
#  '대학',
#  '판매',
#  '사서',
#  '입맛',
#  '옥수수',
#  '옥수수',
#  '품질',
#  '갯수',
#  '찰옥수수',
#  '구매',
#  '옥수수',
#  '알도',
#  '감칠맛',
#  '내년',
#  '의사',
#  '오늘',
#  '알도',
#  '쫀득쫀득',
#  '동생',
#  '선물',
#  '주문',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '옥수수',
#  '비교',
#  '알갱이',
#  '톡톡',
#  '부드러움',
#  '살이',
#  '괴산',
#  '찰옥수수',
#  '정말',
#  '괴산',
#  '찰옥수수',
#  '정말',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '작년',
#  '올해',
#  '주문',
#  '괴산',
#  '찰옥수수',
#  '다른',
#  '가족',
#  '친척',
#  '두루',
#  '포장',
#  '옥수수',
#  '모두',
#  '칭찬',
#  '기분',
#  '월요일',
#  '주문',
#  '금요일',
#  '배송',
#  '완료',
#  '옥수수',
#  '정성',
#  '스레',
#  '감사',
#  '인사',
#  '선물',
#  '좀더',
#  '주문',
#  '사진',
#  '표고',
#  '줄알',
#  '일반',
#  '마트',
#  '더군다나',
#  '날씨',
#  '스티로폼',
#  '박스',
#  '얼음',
#  '버섯',
#  '바람',
#  '냄새',
#  '몇개',
#  '주문',
#  '대학',
#  '찰옥수수',
#  '가족',
#  '쫀득',
#  '날씨',
#  '고생',
#  '다음',
#  '주문',
#  '배송',
#  '물품',
#  '옥수수',
#  '수확',
#  '일이',
#  '예정일',
#  '이상',
#  '지연',
#  '점도',
#  '실망',
#  '옥수수',
#  '상태',
#  '아주',
#  '상태',
#  '실망',
#  '부모님',
#  '주문',
#  '금방',
#  '주문',
#  '부모님',
#  '부탁',
#  '대신',
#  '주문',
#  '칭찬',
#  '하나',
#  '배송',
#  '알도',
#  '하나',
#  '배송',
#  '알도',
#  '괴산',
#  '대학',
#  '찰옥수수',
#  '살이',
#  '톡톡',
#  '괴산',
#  '찰옥수수',
#  '여름',
#  '이면',
#  '주문',
#  '정말',
#  '옥수수',
#  '최고',
#  '쫀득',
#  '모두',
#  '가족',
#  '지인',
#  '냉동',
#  '며칠',
#  '가요',
#  '여름',
#  '고생',
#  '주문',
#  '옥수수',
#  '평가',
#  '남편',
#  '셰프',
#  '인양',
#  '평가',
#  '남편',
#  '질색',
#  '처음',
#  '사본',
#  '대학',
#  '찰옥수수',
#  '평소',
#  '옥수수',
#  '신랑',
#  '신랑',
#  '달짝',
#  '옥수수',
#  '옥수수',
#  '신랑',
#  '표정',
#  '이제',
#  '대학',
#  '찰옥수수',
#  '덕분',
#  '옥수수',
#  '고민',
#  '안해',
#  '배송',
#  '유래',
#  '폭염',
#  '소비자',
#  '옥수수',
#  '나기',
#  '위해',
#  '수고',
#  '괴산',
#  '장터',
#  '직접',
#  '생산',
#  '현장',
#  '경작',
#  '옥수수',
#  '옛날',
#  '옥수수',
#  '강원도',
#  '옥수수',
#  '괴산',
#  '대학',
#  '옥수수',
#  '정말',
#  '폭염',
#  '건강',
#  '유의',
#  '사이트',
#  '구매',
#  '주문',
#  '일단',
#  '박스',
#  '나니',
#  '옥수수',
#  '열기',
#  '알도',
#  '한번',
#  '아기',
#  '간식',
#  '지인',
#  '선물',
#  '정말',
#  '몇번',
#  '옥수수',
#  '제일',
#  '주문',
#  '옥수수',
#  '옥수수',
#  '제일',
#  '아침',
#  '저녁',
#  '주변',
#  '마음',
#  '수고',
#  '가족',
#  '다시',
#  '주문',
#  '와우',
#  '정말',
#  '보람',
#  '포장',
#  '상한',
#  '주문',
#  '고구마',
#  '느낌',
#  '두번째',
#  '호박고구마',
#  '퍽퍽',
#  '아이',
#  '호박고구마',
#  '입맛',
#  '옥수수',
#  '부분',
#  '생기',
#  '약간',
#  '인터넷',
#  '구입',
#  '처음',
#  '빛깔',
#  '거나',
#  '고민',
#  '괴산',
#  '장터',
#  '구입',
#  '마음',
#  '친정엄마',
#  '보시',
#  '주신',
#  '서비스',
#  '보시',
#  '시골',
#  '인심',
#  '자주',
#  '이용',
#  '신토',
#  '농장',
#  '자주',
#  '이용',
#  '고추',
#  '색깔',
#  '품질',
#  '수도',
#  '농사',
#  '수고',
#  '가끔',
#  '인터넷',
#  '물건',
#  '오지',
#  '실망',
#  '이번',
#  '에드',
#  '고추가',
#  '꼭지',
#  '제거',
#  '양건',
#  '구매',
#  '올해',
#  '김장',
#  '빛깔',
#  '고춧가루',
#  '인심',
#  '고추',
#  '내년',
#  '구매',
#  '농장',
#  '바로',
#  '느낌',
#  '벌레',
#  '하나',
#  '쫀득쫀득',
#  '자주',
#  '이용',
#  '괴산',
#  '장터',
#  '이용',
#  '지인',
#  '선물',
#  '역시',
#  '괴산',
#  '옥수수',
#  '라며',
#  '쫀득',
#  '내년',
#  '주문',
#  '옥수수',
#  '끝물',
#  '기대',
#  '오늘',
#  '정말',
#  '옥수수',
#  '알도',
#  '전부',
#  '벌레',
#  '하나',
#  '상품',
#  '카페',
#  '보고',
#  '괴산',
#  '장터',
#  '쇼핑몰',
#  '처음',
#  '건데',
#  '정말',
#  '지금',
#  '품절',
#  '내년',
#  '기약',
#  '옥수수',
#  '청국장',
#  '된장',
#  '고추',
#  '주문',
#  '못난이',
#  '작고',
#  '옥수수',
#  '커서',
#  '부분',
#  '옥수수',
#  '바로',
#  '진공',
#  '포장',
#  '엄마',
#  '지금',
#  '주문',
#  '옥수수',
#  '내외',
#  '옥수수',
#  '못난이',
#  '옥수수',
#  '조금',
#  '도안',
#  '옥수수',
#  '크기',
#  '크기',
#  '알맹이',
#  '택배',
#  '옥수수',
#  '사진',
#  '사진',
#  '주심',
#  '소금',
#  '달달',
#  '쫀득쫀득',
#  '사이즈',
#  '개입',
#  '괴산',
#  '장터',
#  '주문',
#  '황도',
#  '일해',
#  '일품',
#  '검정',
#  '상하',
#  '어제',
#  '하나로마트',
#  '황도',
#  '물건',
#  '화가',
#  '옥수수',
#  '옥수수',
#  '배송',
#  '정말',
#  '주문',
#  '자마자',
#  '시작',
#  '배송',
#  '상태',
#  '정도',
#  ...]

# %%
data3=Counter(data2)
data3
# Out:
# Counter({'출타': 1,
#          '중이': 2,
#          '구매': 43,
#          '확정': 1,
#          '상품': 23,
#          '고구마': 2,
#          '울금': 3,
#          '피로': 1,
#          '회복': 1,
#          '대강': 1,
#          '다시': 13,
#          '입안': 1,
#          '혓바늘': 2,
#          '양치': 1,
#          '금가루': 1,
#          '자고': 1,
#          '배송': 34,
#          '한번': 9,
#          '일시': 2,
#          '문자': 7,
#          '주시': 3,
#          '얼릉': 2,
#          '사기': 1,
#          '이번': 8,
#          '사과': 20,
#          '깜짝': 2,
#          '산후': 1,
#          '박스': 18,
#          '주문': 97,
#          '아기': 3,
#          '남편': 6,
#          '주기도': 1,
#          '아주': 10,
#          '첨가': 1,
#          '쌉싸르': 1,
#          '찌꺼기': 1,
#          '거가': 1,
#          '수입': 2,
#          '귀리': 2,
#          '국산': 2,
#          '괴산군': 1,
#          '관리': 1,
#          '운영': 1,
#          '괴산': 48,
#          '장터': 19,
#          '구입': 28,
#          '아이': 12,
#          '저염식': 1,
#          '김치': 8,
#          '초록색': 1,
#          '겉잎': 1,
#          '우거지': 1,
#          '저장': 1,
#          '옥수수': 137,
#          '지도': 5,
#          '무척': 2,
#          '냉동': 11,
#          '두번째': 5,
#          '도착': 10,
#          '몇개': 6,
#          '보관': 4,
#          '마다': 2,
#          '전자렌지': 1,
#          '살짝': 7,
#          '간식': 3,
#          '예정': 3,
#          '제철': 3,
#          '기대': 7,
#          '날씨': 7,
#          '걱정': 6,
#          '아이스박스': 1,
#          '포장': 21,
#          '냉매': 1,
#          '김장': 10,
#          '절임': 8,
#          '배추': 22,
#          '정말': 38,
#          '올갱이': 5,
#          '껍질': 11,
#          '분리': 1,
#          '시간': 2,
#          '알맹이': 3,
#          '사려': 1,
#          '성분': 1,
#          '생각': 7,
#          '수원': 1,
#          '결과': 2,
#          '만족': 4,
#          '된장': 6,
#          '기분': 5,
#          '건강': 6,
#          '신랑': 5,
#          '일단': 2,
#          '부담': 3,
#          '음식': 3,
#          '이산': 1,
#          '살로': 1,
#          '부추': 1,
#          '거도': 1,
#          '나이': 1,
#          '지그': 1,
#          '어르신': 5,
#          '부탁': 4,
#          '여기저기': 1,
#          '효과': 1,
#          '행사': 4,
#          '전자': 1,
#          '렌즈': 1,
#          '먹기': 8,
#          '아침': 6,
#          '마자': 1,
#          '찜통': 2,
#          '정도': 11,
#          '거리': 1,
#          '사고': 2,
#          '년전': 3,
#          '마을': 2,
#          '이후': 4,
#          '항상': 2,
#          '보리': 2,
#          '결명자': 1,
#          '여기': 2,
#          '정수기': 1,
#          '우려': 1,
#          '농사': 13,
#          '감사': 11,
#          '지인': 7,
#          '소개': 2,
#          '매콤': 1,
#          '자주': 6,
#          '이용': 11,
#          '무청': 1,
#          '시래기': 2,
#          '양으로': 1,
#          '블루베리': 6,
#          '마트': 6,
#          '여명': 1,
#          '농원': 5,
#          '무엇': 3,
#          '듭니': 1,
#          '부모님': 7,
#          '저녁': 4,
#          '의사': 3,
#          '농작물': 3,
#          '봉지': 4,
#          '처음': 16,
#          '계속': 8,
#          '어제': 5,
#          '감자': 11,
#          '반품': 2,
#          '최악': 1,
#          '선택': 1,
#          '건데': 2,
#          '내일': 1,
#          '미리': 1,
#          '연락': 4,
#          '재료': 3,
#          '준비': 1,
#          '토요일': 2,
#          '얼마나': 1,
#          '물이': 1,
#          '뻘겋': 1,
#          '아이스팩': 1,
#          '상태': 13,
#          '조회': 1,
#          '보고': 5,
#          '우선': 2,
#          '밍밍': 2,
#          '동네': 2,
#          '우리': 7,
#          '엄마': 6,
#          '플레인': 1,
#          '요거트': 1,
#          '그냥': 3,
#          '워낙': 1,
#          '때문': 2,
#          '기전': 2,
#          '배수': 1,
#          '도움': 1,
#          '가을': 2,
#          '집안일': 1,
#          '작년': 8,
#          '남작': 2,
#          '품질': 9,
#          '최상급': 1,
#          '올해': 11,
#          '오직': 1,
#          '위해': 4,
#          '전화': 2,
#          '달리': 1,
#          '호미': 1,
#          '거림': 1,
#          '품종': 2,
#          '전혀': 2,
#          '미감': 1,
#          '하자': 1,
#          '인증서': 1,
#          '신경': 2,
#          '보람': 2,
#          '물건': 5,
#          '확인': 3,
#          '반찬': 1,
#          '읍니': 3,
#          '농장': 11,
#          '세번': 1,
#          '발송': 2,
#          '무선': 1,
#          '수확': 5,
#          '일도': 1,
#          '해주': 1,
#          '추가': 3,
#          '자루': 3,
#          '가격': 8,
#          '번창': 2,
#          '크기': 13,
#          '일정': 1,
#          '한편': 1,
#          '쫄깃': 3,
#          '친정': 5,
#          '선물': 11,
#          '언니': 2,
#          '특유': 1,
#          '감칠맛': 3,
#          '진짜': 3,
#          '흐믓했어': 1,
#          '여름': 9,
#          '고생': 8,
#          '후기': 3,
#          '귀차니즘': 1,
#          '주변': 2,
#          '모든': 1,
#          '식구': 5,
#          '브로콜리': 2,
#          '낱개': 1,
#          '장아찌': 1,
#          '주소': 2,
#          '입력': 1,
#          '불구': 2,
#          '일이': 3,
#          '엉터리': 1,
#          '잘못': 1,
#          '다음': 4,
#          '우여곡절': 1,
#          '지역': 1,
#          '농산물': 2,
#          '시들시들': 1,
#          '누렇': 1,
#          '대학': 28,
#          '쫀득쫀득합니': 1,
#          '쫀득합니': 1,
#          '쫀득': 4,
#          '검색': 3,
#          '푸른': 2,
#          '예약': 3,
#          '할인': 2,
#          '반신': 1,
#          '사실': 1,
#          '번가': 1,
#          '찰옥수수': 35,
#          '낭패': 1,
#          '서리': 2,
#          '도안': 2,
#          '차고': 3,
#          '작고': 5,
#          '완전': 6,
#          '내년': 13,
#          '어머니': 3,
#          '보더': 1,
#          '오늘': 9,
#          '바로': 8,
#          '판매': 8,
#          '농부': 4,
#          '강원도': 2,
#          '안방': 1,
#          '제품': 6,
#          '텃밭': 1,
#          '쭈욱': 1,
#          '반음': 1,
#          '실로': 1,
#          '장연': 2,
#          '해먹': 2,
#          '거나': 2,
#          '우체국': 1,
#          '이나': 1,
#          '시기': 1,
#          '이면': 3,
#          '포대': 1,
#          '이상은': 1,
#          '추천': 1,
#          '선별': 2,
#          '쭈우욱': 1,
#          '단골': 2,
#          '수고': 6,
#          '제대로': 5,
#          '볼때': 1,
#          '식사': 1,
#          '대용': 1,
#          '대성공': 2,
#          '시댁': 2,
#          '지씨': 1,
#          '농가': 2,
#          '유기농': 17,
#          '농약': 4,
#          '덕분': 4,
#          '톡톡': 5,
#          '비교': 2,
#          '하모니카': 1,
#          '불면': 1,
#          '고산': 1,
#          '최고': 3,
#          '학생': 2,
#          '가지': 1,
#          '인연': 1,
#          '시즌': 2,
#          '전해': 1,
#          '매년': 5,
#          '미국': 1,
#          '귀국': 3,
#          '사서': 3,
#          '입맛': 3,
#          '갯수': 3,
#          '알도': 13,
#          '쫀득쫀득': 3,
#          '동생': 4,
#          '알갱이': 3,
#          '부드러움': 1,
#          '살이': 2,
#          '다른': 10,
#          '가족': 9,
#          '친척': 1,
#          '두루': 1,
#          '모두': 5,
#          '칭찬': 3,
#          '월요일': 2,
#          '금요일': 1,
#          '완료': 1,
#          '정성': 3,
#          '스레': 1,
#          '인사': 1,
#          '좀더': 3,
#          '사진': 9,
#          '표고': 2,
#          '줄알': 1,
#          '일반': 3,
#          '더군다나': 1,
#          '스티로폼': 1,
#          '얼음': 2,
#          '버섯': 1,
#          '바람': 2,
#          '냄새': 3,
#          '물품': 1,
#          '예정일': 1,
#          '이상': 5,
#          '지연': 1,
#          '점도': 1,
#          '실망': 13,
#          '금방': 2,
#          '대신': 1,
#          '하나': 10,
#          '며칠': 3,
#          '가요': 1,
#          '평가': 2,
#          '셰프': 1,
#          '인양': 1,
#          '질색': 1,
#          '사본': 1,
#          '평소': 2,
#          '달짝': 1,
#          '표정': 1,
#          '이제': 2,
#          '고민': 2,
#          '안해': 1,
#          '유래': 1,
#          '폭염': 2,
#          '소비자': 1,
#          '나기': 2,
#          '직접': 2,
#          '생산': 1,
#          '현장': 1,
#          '경작': 1,
#          '옛날': 1,
#          '유의': 2,
#          '사이트': 3,
#          '나니': 2,
#          '열기': 1,
#          '몇번': 1,
#          '제일': 3,
#          '마음': 5,
#          '와우': 1,
#          '상한': 2,
#          '느낌': 3,
#          '호박고구마': 2,
#          '퍽퍽': 1,
#          '부분': 5,
#          '생기': 1,
#          '약간': 5,
#          '인터넷': 2,
#          '빛깔': 3,
#          '친정엄마': 3,
#          '보시': 2,
#          '주신': 2,
#          '서비스': 2,
#          '시골': 4,
#          '인심': 3,
#          '신토': 1,
#          '고추': 27,
#          '색깔': 5,
#          '수도': 2,
#          '가끔': 2,
#          '오지': 1,
#          '에드': 1,
#          '고추가': 4,
#          '꼭지': 4,
#          '제거': 1,
#          '양건': 1,
#          '고춧가루': 1,
#          '벌레': 8,
#          '역시': 5,
#          '라며': 3,
#          '끝물': 1,
#          '전부': 1,
#          '카페': 1,
#          '쇼핑몰': 1,
#          '지금': 6,
#          '품절': 9,
#          '기약': 1,
#          '청국장': 2,
#          '못난이': 5,
#          '커서': 3,
#          '진공': 7,
#          '내외': 1,
#          '조금': 10,
#          '택배': 5,
#          '주심': 1,
#          '소금': 3,
#          '달달': 1,
#          '사이즈': 6,
#          '개입': 1,
#          '황도': 2,
#          '일해': 1,
#          '일품': 2,
#          '검정': 1,
#          '상하': 1,
#          '하나로마트': 1,
#          '화가': 1,
#          '자마자': 2,
#          '시작': 2,
#          '거의': 5,
#          '제법': 1,
#          '도나': 1,
#          '고추장': 5,
#          '간장': 3,
#          '집밥': 1,
#          '기본': 2,
#          '혹시': 3,
#          '모양': 5,
#          '자체': 2,
#          '과정': 1,
#          '내용물': 3,
#          '무게': 2,
#          '스티': 1,
#          '주의': 1,
#          '사항': 1,
#          '표시': 1,
#          '장연면': 1,
#          '건조': 4,
#          '가루': 4,
#          '식용': 1,
#          '사용': 2,
#          '주부': 1,
#          '입장': 1,
#          '물말': 1,
#          '바렘': 1,
#          '신분': 1,
#          '궁굼': 1,
#          '단지': 2,
#          '일찍': 3,
#          '은색': 2,
#          '사이': 3,
#          '자연': 2,
#          '동시': 1,
#          '전자레인지': 1,
#          '먹음': 1,
#          '개인': 1,
#          '리가': 1,
#          '색도': 1,
#          '명시': 1,
#          '절대': 2,
#          '먼저': 2,
#          '약속': 1,
#          '자꾸': 1,
#          '취소': 1,
#          '선유동': 1,
#          '아야': 1,
#          '송료': 1,
#          '지불': 1,
#          '외유': 1,
#          '제사': 1,
#          '항의': 1,
#          '양도': 1,
#          '해이': 1,
#          '고추잠자리': 1,
#          '골드': 1,
#          '스피노자': 1,
#          '편이': 1,
#          '평이': 2,
#          '날짜': 1,
#          '배추속': 1,
#          '단맛': 2,
#          '푹절': 1,
#          '안절': 1,
#          '황금': 5,
#          '배송비': 2,
#          '환불': 1,
#          '이변': 1,
#          '여지': 1,
#          '어른': 1,
#          '꼭지딴': 1,
#          '수가': 1,
#          '오차': 1,
#          '믿음': 2,
#          '하니': 2,
#          '간도': 1,
#          '불량': 1,
#          '시식': 1,
#          '당부': 1,
#          '다시금': 1,
#          '끝맛': 1,
#          '백도': 1,
#          '감초': 1,
#          '생강': 1,
#          '함량': 1,
#          '도라지': 1,
#          '재래식': 1,
#          '대부분': 3,
#          '상처': 1,
#          '드네': 1,
#          '기도': 1,
#          '난사': 1,
#          '길위': 1,
#          '지난': 1,
#          '열매': 1,
#          '겨울': 2,
#          '내내': 3,
#          '부사': 1,
#          '지은': 1,
#          '똘똘하': 1,
#          '빠알간': 1,
#          '책상': 1,
#          '서로': 2,
#          '물물교환': 1,
#          '세상': 1,
#          '한해': 1,
#          '솔뫼': 2,
#          '가장': 3,
#          '유리': 2,
#          '환경호르몬': 2,
#          '먹거리': 3,
#          '결혼': 1,
#          '자재': 1,
#          '친환경': 2,
#          '관심': 1,
#          '안심': 2,
#          '볶음': 2,
#          '애용': 2,
#          '두시': 1,
#          '들깨': 3,
#          '유기농법': 1,
#          '화학': 2,
#          '비료': 2,
#          '여러': 1,
#          '라면': 1,
#          '사랑': 1,
#          '합격': 1,
#          '청정': 1,
#          '제공': 2,
#          '곳간': 1,
#          '지기': 1,
#          '정월대보름': 1,
#          '찹쌀': 1,
#          '오곡밥': 1,
#          '세트': 1,
#          '만복': 1,
#          '유지': 1,
#          '정보': 3,
#          '하루': 1,
#          '맛보기': 1,
#          '생즙': 1,
#          '사과쥬스': 1,
#          '후식': 1,
#          '과일': 2,
#          '해동': 1,
#          '차이': 2,
#          '피고': 1,
#          '나무': 1,
#          '문의': 1,
#          '응대': 1,
#          '매니아': 1,
#          '된거': 1,
#          '주말': 1,
#          '미선나무': 1,
#          '흰색': 1,
#          '상아색': 1,
#          '정성껏': 1,
#          '일사이': 1,
#          '피어': 1,
#          '보렵니': 1,
#          '청결': 3,
#          '강추': 1,
#          '에어': 2,
#          '휴게소': 1,
#          '배기': 1,
#          '조카': 1,
#          '다만': 1,
#          '저번': 3,
#          '무른': 1,
#          '동동': 1,
#          '한잔': 1,
#          '매일': 1,
#          '양배추': 3,
#          '한살림': 1,
#          '생협': 1,
#          '육수': 1,
#          '개중': 3,
#          '여유': 1,
#          '마감': 1,
#          '타임': 1,
#          '가로': 1,
#          '친절': 2,
#          '파시': 1,
#          '대박': 2,
#          '시중': 1,
#          '중국산': 1,
#          '조선': 1,
#          '나물': 1,
#          '요리': 1,
#          '충격': 1,
#          '줄줄': 1,
#          '안이': 1,
#          '꼬리': 3,
#          '용기': 1,
#          '표고버섯': 1,
#          '일부분': 1,
#          '스프': 1,
#          '벼르': 1,
#          '생산자': 2,
#          '수미': 1,
#          '도로': 1,
#          '일주일': 1,
#          '원래': 1,
#          '아해': 1,
#          '버터': 1,
#          '프라이어': 1,
#          '설탕': 1,
#          '애도': 1,
#          '나머지': 1,
#          '생으로': 2,
#          '출시': 1,
#          '소화': 1,
#          '매우': 3,
#          '여물': 2,
#          '낟알': 1,
#          '묶음': 1,
#          '실수': 1,
#          '문제': 1,
#          '설명': 1,
#          '괜장히': 1,
#          '손질': 2,
#          '개식': 1,
#          '회신': 1,
#          '예전': 2,
#          '개정': 3,
#          '말로': 1,
#          '신세계': 1,
#          '달기': 1,
#          '달구': 1,
#          '벌써': 2,
#          '네로': 1,
#          '반토막': 1,
#          '효성': 1,
#          '글쎄': 1,
#          '쌍둥이': 1,
#          '부모': 1,
#          '차서': 1,
#          '말씀': 1,
#          '달라': 1,
#          '정혹': 1,
#          '뻐르': 1,
#          '돟아': 1,
#          '운영자': 2,
#          '그때': 1,
#          '집사람': 1,
#          '동료': 1,
#          '홍보': 1,
#          '기회': 1,
#          '더욱': 1,
#          '소리': 1,
#          '즐거움': 1,
#          '또한': 2,
#          '장마철': 2,
#          '선지': 1,
#          '엉망': 1,
#          '온통': 1,
#          '더러': 1,
#          '센스': 1,
#          '참고': 1,
#          '한참': 2,
#          '덜영글었': 1,
#          '할껄': 1,
#          '프로': 1,
#          '재주': 1,
#          '물어': 1,
#          '겉껍질': 1,
#          '안쪽': 1,
#          '오늘아침': 1,
#          '순간': 1,
#          '고해': 1,
#          '장마': 1,
#          '틀니': 1,
#          '아버지': 1,
#          '수염': 2,
#          '대요': 1,
#          '절반': 1,
#          '욕심': 1,
#          '감안': 1,
#          '이해': 2,
#          '사면': 1,
#          '가치': 1,
#          '노하우': 1,
#          '이쯤': 1,
#          '의도': 1,
#          '종이': 1,
#          '상자': 3,
#          '연한': 1,
#          '인빌': 1,
#          '어째튼': 1,
#          '주인': 1,
#          '외국': 1,
#          '생활': 1,
#          '더위': 1,
#          '분해': 1,
#          '압력솥': 1,
#          '술술': 1,
#          '강냉이': 1,
#          '목요일': 1,
#          '이틀': 2,
#          '어물었': 1,
#          '깜빡': 1,
#          '맜있네': 1,
#          '조만간': 1,
#          '얼른': 2,
#          '예상': 1,
#          '로만': 1,
#          '재배': 3,
#          '전번': 1,
#          '어디': 1,
#          '입처': 1,
#          '내용': 2,
#          '기재': 1,
#          '그동안': 1,
#          '만약': 1,
#          '문구': 1,
#          '대체로': 1,
#          '껍찔': 1,
#          '이점': 1,
#          '솔질': 1,
#          '해도': 1,
#          '숙성': 2,
#          '꿀맛': 1,
#          '기쓰네': 1,
#          '발견': 1,
#          '역쉬': 1,
#          '수량': 1,
#          '사은': 1,
#          '렵니': 1,
#          '만큼': 1,
#          '씨알': 1,
#          '전체': 1,
#          '간격': 1,
#          '깜놀': 1,
#          '사라': 1,
#          '안주': 1,
#          '주님': 1,
#          '정리': 1,
#          '존득존득': 1,
#          '고향': 2,
#          '빻았는데': 1,
#          '한우': 1,
#          '고기': 1,
#          '양지': 1,
#          '쭉쭉': 1,
#          '사람': 1,
#          '아쉬움': 1,
#          '애벌레': 1,
#          '마리': 2,
#          '중간': 1,
#          '사지': 1,
#          '빻는데': 1,
#          '방앗간': 5,
#          '빻러': 1,
#          '오라': 2,
#          '빻지': 1,
#          '이사': 1,
#          '빻었': 1,
#          '진액': 1,
#          '무려': 1,
#          '주일': 1,
#          '만인': 1,
#          '빻으러': 1,
#          '빠꾸': 1,
#          '군데': 1,
#          '기계': 1,
#          '장난': 1,
#          '문전': 1,
#          '박대': 1,
#          '제습기': 1,
#          '베란다': 1,
#          '말리': 1,
#          '눅눅': 1,
#          '지네': 1,
#          '명절': 1,
#          '다가': 1,
#          '미나': 1,
#          '마개': 3,
#          '구멍': 1,
#          '술병': 1,
#          '부가': 1,
#          '진공상태': 1,
#          '수정': 1,
#          '여름내': 1,
#          '충남': 1,
#          '근대': 1,
#          '물엿': 1,
#          '얘기': 1,
#          '설마': 1,
#          '초당': 1,
#          '좀컷': 1,
#          '번거': 1,
#          '와인': 1,
#          '마시기': 1,
#          '일석이조': 1,
#          '모험': 2,
#          '이유': 1,
#          '을해': 1,
#          '이벤트': 1,
#          '용해': 1,
#          '그대로': 1,
#          '항산화물질': 1,
#          '폴리페놀': 1,
#          '마침': 1,
#          '반값': 1,
#          '용량': 1,
#          '도크': 1,
#          '떫은맛': 1,
#          '유통': 1,
#          '기한': 1})

# %%
data4=data3.most_common(100)
data4
# Out:
# [('옥수수', 137),
#  ('주문', 97),
#  ('괴산', 48),
#  ('구매', 43),
#  ('정말', 38),
#  ('찰옥수수', 35),
#  ('배송', 34),
#  ('구입', 28),
#  ('대학', 28),
#  ('고추', 27),
#  ('상품', 23),
#  ('배추', 22),
#  ('포장', 21),
#  ('사과', 20),
#  ('장터', 19),
#  ('박스', 18),
#  ('유기농', 17),
#  ('처음', 16),
#  ('다시', 13),
#  ('농사', 13),
#  ('상태', 13),
#  ('크기', 13),
#  ('내년', 13),
#  ('알도', 13),
#  ('실망', 13),
#  ('아이', 12),
#  ('냉동', 11),
#  ('껍질', 11),
#  ('정도', 11),
#  ('감사', 11),
#  ('이용', 11),
#  ('감자', 11),
#  ('올해', 11),
#  ('농장', 11),
#  ('선물', 11),
#  ('아주', 10),
#  ('도착', 10),
#  ('김장', 10),
#  ('다른', 10),
#  ('하나', 10),
#  ('조금', 10),
#  ('한번', 9),
#  ('품질', 9),
#  ('여름', 9),
#  ('오늘', 9),
#  ('가족', 9),
#  ('사진', 9),
#  ('품절', 9),
#  ('이번', 8),
#  ('김치', 8),
#  ('절임', 8),
#  ('먹기', 8),
#  ('계속', 8),
#  ('작년', 8),
#  ('가격', 8),
#  ('고생', 8),
#  ('바로', 8),
#  ('판매', 8),
#  ('벌레', 8),
#  ('문자', 7),
#  ('살짝', 7),
#  ('기대', 7),
#  ('날씨', 7),
#  ('생각', 7),
#  ('지인', 7),
#  ('부모님', 7),
#  ('우리', 7),
#  ('진공', 7),
#  ('남편', 6),
#  ('몇개', 6),
#  ('걱정', 6),
#  ('된장', 6),
#  ('건강', 6),
#  ('아침', 6),
#  ('자주', 6),
#  ('블루베리', 6),
#  ('마트', 6),
#  ('엄마', 6),
#  ('완전', 6),
#  ('제품', 6),
#  ('수고', 6),
#  ('지금', 6),
#  ('사이즈', 6),
#  ('지도', 5),
#  ('두번째', 5),
#  ('올갱이', 5),
#  ('기분', 5),
#  ('신랑', 5),
#  ('어르신', 5),
#  ('농원', 5),
#  ('어제', 5),
#  ('보고', 5),
#  ('물건', 5),
#  ('수확', 5),
#  ('친정', 5),
#  ('식구', 5),
#  ('작고', 5),
#  ('제대로', 5),
#  ('톡톡', 5),
#  ('매년', 5)]

# %%
data5=dict(data4)
data5
# Out:
# {'옥수수': 137,
#  '주문': 97,
#  '괴산': 48,
#  '구매': 43,
#  '정말': 38,
#  '찰옥수수': 35,
#  '배송': 34,
#  '구입': 28,
#  '대학': 28,
#  '고추': 27,
#  '상품': 23,
#  '배추': 22,
#  '포장': 21,
#  '사과': 20,
#  '장터': 19,
#  '박스': 18,
#  '유기농': 17,
#  '처음': 16,
#  '다시': 13,
#  '농사': 13,
#  '상태': 13,
#  '크기': 13,
#  '내년': 13,
#  '알도': 13,
#  '실망': 13,
#  '아이': 12,
#  '냉동': 11,
#  '껍질': 11,
#  '정도': 11,
#  '감사': 11,
#  '이용': 11,
#  '감자': 11,
#  '올해': 11,
#  '농장': 11,
#  '선물': 11,
#  '아주': 10,
#  '도착': 10,
#  '김장': 10,
#  '다른': 10,
#  '하나': 10,
#  '조금': 10,
#  '한번': 9,
#  '품질': 9,
#  '여름': 9,
#  '오늘': 9,
#  '가족': 9,
#  '사진': 9,
#  '품절': 9,
#  '이번': 8,
#  '김치': 8,
#  '절임': 8,
#  '먹기': 8,
#  '계속': 8,
#  '작년': 8,
#  '가격': 8,
#  '고생': 8,
#  '바로': 8,
#  '판매': 8,
#  '벌레': 8,
#  '문자': 7,
#  '살짝': 7,
#  '기대': 7,
#  '날씨': 7,
#  '생각': 7,
#  '지인': 7,
#  '부모님': 7,
#  '우리': 7,
#  '진공': 7,
#  '남편': 6,
#  '몇개': 6,
#  '걱정': 6,
#  '된장': 6,
#  '건강': 6,
#  '아침': 6,
#  '자주': 6,
#  '블루베리': 6,
#  '마트': 6,
#  '엄마': 6,
#  '완전': 6,
#  '제품': 6,
#  '수고': 6,
#  '지금': 6,
#  '사이즈': 6,
#  '지도': 5,
#  '두번째': 5,
#  '올갱이': 5,
#  '기분': 5,
#  '신랑': 5,
#  '어르신': 5,
#  '농원': 5,
#  '어제': 5,
#  '보고': 5,
#  '물건': 5,
#  '수확': 5,
#  '친정': 5,
#  '식구': 5,
#  '작고': 5,
#  '제대로': 5,
#  '톡톡': 5,
#  '매년': 5}

# %%
wc=WordCloud(font_path='C:\Windows\Fonts\malgun.ttf', background_color='white')
g_data=wc.generate_from_frequencies(data5)
plt.figure(figsize=(10,10))
plt.imshow(g_data)
plt.axis('off')
plt.show()
