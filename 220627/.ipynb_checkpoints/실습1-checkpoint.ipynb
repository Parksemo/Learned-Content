# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://finance.naver.com/item/sise_time.naver'

# %%
base_params = {
    'code':'005930',
    'thistime':'20220627161132'
}

# %%
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}

# %%
resp = requests.get(base_url, base_params, headers=headers)

# %%
resp.text
# Out:
# '<html lang="ko">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\n<title>네이버 금융</title>\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/common.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/layout.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/main.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock2.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock3.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/world.css">\n</head>\n<body>\n<script
# ...

# %%
soup = BeautifulSoup(resp.text)

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 금융</title>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220615142521/css/world.css" rel="stylesheet" type="text/css"/>
# </head>
# ...

# %%
time = soup.select('.tah.p10.gray03')

# %%
time
# Out:
# [<span class="tah p10 gray03">15:58</span>,
#  <span class="tah p10 gray03">15:57</span>,
#  <span class="tah p10 gray03">15:56</span>,
#  <span class="tah p10 gray03">15:55</span>,
#  <span class="tah p10 gray03">15:54</span>,
#  <span class="tah p10 gray03">15:53</span>,
#  <span class="tah p10 gray03">15:52</span>,
#  <span class="tah p10 gray03">15:51</span>,
#  <span class="tah p10 gray03">15:50</span>,
#  <span class="tah p10 gray03">15:49</span>]

# %%
value = soup.select('.num')

# %%
value
# Out:
# [<td class="num"><span class="tah p11">58,800</span></td>,
#  <td class="num">
#  <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
#  				400
#  				</span>
#  </td>,
#  <td class="num"><span class="tah p11">58,900</span></td>,
#  <td class="num"><span class="tah p11">58,800</span></td>,
#  <td class="num"><span class="tah p11">17,894,851</span></td>,
#  <td class="num"><span class="tah p11">167</span></td>,
#  <td class="num"><span class="tah p11">58,800</span></td>,
#  <td class="num">
#  <img alt="상승" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" style="margin-right:4px;" width="7"/><span class="tah p11 red02">
#  				400
#  				</span>
#  </td>,
#  <td class="num"><span class="tah p11">58,900</span></td>,
#  <td class="num"><span class="tah p11">58,800</span></td>,
#  <td class="num"><span class="tah p11">17,894,684</span></td>,
# ...
