# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.wadiz.kr/web/wreward/main'

# %%
params = {
    'keyword':'',
    'endYn':'ALL',
    'order':'recommend'   
}

# %%
resp = requests.get(url, params)

# %%
resp.text
# Out:
# '\n\n\n\n<!-- froala_editor_version 3.2.7 -->\n\n\n\n<!doctype html>\n<html lang="ko">\n<head>\n<!-- froala_editor_version 3.2.7 -->\n<style>.async-hide { opacity: 0 !important} </style>\n<script>(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\nh.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};\n(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;\n})(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,\n{\'GTM-NDMQ9N4\':true});</script>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width,initial-scale=1,shrink-to-fit=no,user-scalable=no,viewport-fit=cover">\n<meta name="description" content="테크, 패션, 푸드, 뷰티, 홈리빙까지. 와디즈 펀딩으로 매일 새로운 일상을 발견하고, 와디즈 스토어에서 새로운 쇼핑을 만나보세요.">\n<meta property="fb:app_id" content="190622721088710">\n<meta property="og:type" content="website">\n<meta property="og:locale" content="ko_KR">\n<meta propert
# ...

# %%
soup = BeautifulSoup(resp.text)

# %%
soup
# Out:
# <!-- froala_editor_version 3.2.7 --><!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- froala_editor_version 3.2.7 -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-NDMQ9N4':true});</script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width,initial-scale=1,shrink-to-fit=no,user-scalable=no,viewport-fit=cover" name="viewport"/>
# <meta content="테크, 패션, 푸드, 뷰티, 홈리빙까지. 와디즈 펀딩으로 매일 새로운 일상을 발견하고, 와디즈 스토어에서 새로운 쇼핑을 만나보세요." name="description"/>
# <meta content="190622721088710" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# ...

# %%
time = soup.select('.ProjectCardList_list__1YBa2')

# %%
time
# Out:
# [<div class="ProjectCardList_list__1YBa2"><div class="ProjectCardList_item__1owJa"><div><div class="CommonCard_container__e_ebQ CommonCard_squareSmall__1Cdkn"><span aria-hidden="true" class="CardLink_link__1k83H CommonCard_image__vaqkf" tabindex="-1"><div class="CommonCard_rect__2wpm4"><span class="CommonCard_background__3toTR" style="css-text:"></span></div></span><div class="CommonCard_info__1f4kq"><div class="RewardProjectCard_info__3JFub"><div class="RewardProjectCard_infoTop__3QR5w"><span class="CardLink_link__1k83H"><p class="CommonCard_title__1oKJY RewardProjectCard_title__iUtvs"><strong></strong></p></span><div><span class="RewardProjectCard_category__2muXk"></span><span class="RewardProjectCard_makerName__2q4oH"></span></div></div><div class="RewardProjectCard_gauge__3p9US"><span style="width:0%"></span></div><span class="RewardProjectCard_percent__3TW4_">0%</span><span class="RewardProjectCard_amount__2AyJF">0원</span><span class="RewardProjectCard_days__3eece"></span></div>
# ...
