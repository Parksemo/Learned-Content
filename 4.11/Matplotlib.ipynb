# %% [markdown]
# ### 시각화
# 1. 초기 설정

# %%
import matplotlib.pyplot as plt
#import matplotlib
#matplotlib.rcParams['font.family']='Malgun Gothic' #Window 한글 표현
#matplotlib.rcParams['font.family']='Applegothic' #Mac
#matplotlib.rcParams['axes.unicode_minus']=False #음수표현을 위한 속성값 변경

# %%
x=[1,2,3]
y=[-2,-4,-8]
y1=[1,3,7]
plt.plot(x,y)#맷플롯에 data 전달
plt.plot(x,y1)
plt.show()

# %%
plt.plot(x,y1)
plt.show()

# %%
import numpy as np
X_1=range(100)
Y_1=[np.cos(i) for i in X_1]

X_2=range(100)
Y_2=[np.sin(i) for i in X_1]
plt.plot(X_1,Y_1)
plt.plot(X_2,Y_2)

# %%
fig, ax=plt.subplots()
X_1=range(100)
Y_1=[np.cos(i) for i in X_1]
ax.plot(X_1,Y_1)
ax.set(title="cos_g", xlabel='X', ylabel='Y')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[-4,-8,-6]
plt.plot(x,y)#선그래프
plt.title("꺽은선 그래프",fontdict={'family':"Malgun Gothic",'size':25})
plt.xlabel("가로축",color="#00aa00",fontdict={'family':"Malgun Gothic",'size':25},loc='left')
#가로 1eft, center,right
plt.ylabel("세로축",color="#0000aa",fontdict={'family':"Malgun Gothic",'size':25},loc='bottom')
#세로 top, center, bottom
plt.show()

# %%
import matplotlib.font_manager
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'cmss10',
#  'DejaVu Serif Display',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'cmsy10',
#  'cmtt10',
#  'DejaVu Serif',
#  'cmr10',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'cmb10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'Microsoft PhagsPa',
#  'Gill Sans MT',
#  'Berlin Sans FB',
#  'Calibri',
#  'Eras Light ITC',
#  'Yu Gothic',
#  'Ink Free',
#  'Blackadder ITC',
#  'Franklin Gothic Demi',
#  'Cambria',
#  'Cambria',
#  'Century Schoolbook',
#  'Palace Script MT',
# ...

# %%
x=[1,2,3]
y=[4,8,6]
plt.plot(x,y)#선그래프
plt.title("꺽은선 그래프",fontdict={'family':"Malgun Gothic",'size':25})
plt.xlabel("가로축",color="#00aa00",fontdict={'family':"Malgun Gothic",'size':25},loc='left')
#가로 1eft, center,right
plt.ylabel("세로축",color="#0000aa",fontdict={'family':"Malgun Gothic",'size':25},loc='bottom')
#세로 top, center, bottom
plt.show()

# %%
#그림생성
fig=plt.figure()
fig.set_size_inches(10,10)
import numpy as np
X_1=range(100)
Y_1=[np.cos(i) for i in X_1]
X_2=range(100)
Y_2=[np.sin(i) for i in X_1]

#그래프생성
ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)
ax_1.plot(X_1,Y_1)
ax_2.plot(X_2,Y_2)
plt.show()

# %%
fig, ax=plt.subplots(nrows=2,ncols=2)
print(ax)
print(type(ax))
# Out:
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]
# <class 'numpy.ndarray'>

# %%
fig, ax=plt.subplots(2,2)
x=np.linspace(-1,1,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.exp(x)
ax[0,0].plot(x,y1)
ax[0,1].plot(x,y2)
ax[1,0].plot(x,y3)
ax[1,1].plot(x,y4)
plt.show()

# %%
ax1=plt.subplot(321)
plt.plot(x,y1)
ax2=plt.subplot(322)
plt.plot(x,y2)
ax3=plt.subplot(313)
plt.plot(x,y3)
ax4=plt.subplot(325)
plt.plot(x,y3)
plt.show()

# %%
ax1=plt.subplot(331)
plt.plot(x,y1)
ax2=plt.subplot(513)
plt.plot(x,y2)

# %%
plt.plot(x,y1,label="sin")
plt.plot(x,y2,label="cos")
#plt.plot(x,y1)
#plt.plot(x,y2)
plt.legend(loc=(0.5,0.5))#0~1
plt.show()

# %%
plt.plot(x,y1,label="sin",color="#0000aa")
plt.plot(x,y2,label="cos",c="g")
plt.show()

# %%
plt.plot(x,y1,label="sin",color="#0000aa",linestyle="dashed")
plt.plot(x,y2,label="cos",c="r",ls="dotted")
plt.title("all_p")
plt.show()

# %%
x=np.linspace(-1,1,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.exp(x)
plt.plot(x,y1,c='r',ls='dashed',label='sin')
plt.plot(x,y2,c='b',ls='dotted',label='cos')
plt.plot(x,y3,c='g',ls='solid',label='tan')
plt.plot(x,y4,c='c',label='exp')
plt.legend(loc="best",shadow=True)

# %%
x=np.linspace(-1,1,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.exp(x)
plt.plot(x,y1,c='r',ls='dashed',label='sin',marker='o')
plt.plot(x,y2,c='b',ls='dotted',label='cos',marker='*')
plt.plot(x,y3,c='g',ls='solid',label='tan')
plt.plot(x,y4,c='c',ls='None',label='exp',linewidth=5)
plt.legend(loc="best",shadow=True)

# %%
X=[1,2,3]
Y=[1,5,15]
X1=[1,3]
Y1=[1,15]
plt.plot(X,Y,marker='v')
plt.plot(X1,Y1,marker='v')
