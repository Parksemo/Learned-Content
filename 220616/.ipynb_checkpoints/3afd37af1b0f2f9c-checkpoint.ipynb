# %%
import numpy as np
import pandas as pd
import csv

from selenium import webdriver
import chromedriver_autoinstaller

from tqdm import tqdm, tqdm_notebook
from tqdm.notebook import tqdm
import re
from time import sleep
import time
import warnings
warnings.filterwarnings('ignore')
import random
t=random.choice([3,4,5])

# %%
def 리뷰크롤링(key):
    title="리뷰","평점"
    f=open(f"{key}.csv","w",encoding='utf-8-sig',newline="")
    writer=csv.writer(f)
    writer.writerow(title)
    chrome_path=chromedriver_autoinstaller.install()
    driver = webdriver.Chrome(chrome_path)
    time.sleep(3)
    try:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        driver.find_element_by_xpath('//*[@id="typeahead_results"]/a[1]').click()
        driver.implicitly_wait(10)
    except:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        driver.find_element_by_xpath('//*[@id="typeahead_results"]/a[1]').click()
        driver.implicitly_wait(10)        
    out_re=[]
    c = True
    while c:
        
        try:
            driver.execute_script("window.scrollTo(0, 5500)")
            driver.implicitly_wait(t)
            for j in tqdm(range(1,11)):
                #time.sleep(2)
                try:
                    review=[driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[5]/div[1]/div/span').text
                           ,driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[2]/*[name()="svg"]').get_attribute('aria-label')
                           ]
                    review[1] = review[1].replace('풍선 5개 중 ','')                    
                    #time.sleep(t)
                    out_re.append(review)
                except:
                    break
            driver.implicitly_wait(t)
    #         print(out_re)
            element = driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[10]/span/div')
            driver.execute_script('arguments[0].scrollIntoView(true);', element)
            driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[11]/div[1]/div/div[1]/div[2]/div/a/*[name()="svg"]').click()
            driver.implicitly_wait(t)
        except:
            c=False

    writer.writerows(out_re)
    f.close()   
    df=pd.read_csv(f'{key}.csv')
    return df

# %%
리뷰크롤링('부산민주공원')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#                                                    리뷰   평점
# 0   벚꼬이 지고나면 왕겹벚꽃이 피는 시기에요.\n4월중순기준입니다. 차량이 아주 복잡해...  5.0
# 1   중앙도서관이 있어 자주 가는 곳입니다.1호선 지하철 동대신역 앞에 중구 1번 마을버...  5.0
# 2   부산 민주공원은 영주동 산 자락에 위치하고 있습니다. 우리 선열들의 영령을 느낄 수...  5.0
# 3   부산 겹벚꽃 명소로 알려져서 처음 가보게 되었는데 겹벚꽃이 예쁘게 펴 있어서 꽃구경...  5.0
# 4   민주항쟁기념관 내부가 꽤 잘되어있습니다~ 그당시에 쓰던 옷들, 편지 등 전시가 잘되...  5.0
# 5   부산역에서 버스를 타고 종점에 내리면 민주공원이 보입니다. 이곳에서 보이는 부산의 ...  4.0
# 6   민주공원은 높은곳에있어서 걸어가기가 힘이들지만 올라가서보면 경치가 너무 좋습니다.밤...  4.0
# 7   관광객들은 잘 모르지만 부산의 전망을 즐길 수 있는 좋은 장소입니다.\n공원입구까지...  5.0
# 8   계단은 많지만 올라가면 남포동 시내가 다 볼 수 있습니다. 공원 안에서 벤치가 많아...  5.0
# 9   버스로 공원 바로 앞까지 접근할 수 있습니다. 올라가는 도중 산을 타고 굽이굽이 버...  5.0
# 10  충혼탑이 멋지게 우뚝 선 민주공원입니다.\n많은 홍보가 필요한 곳이라서 아쉬운 곳이...  5.0
# 11  부산항을 한눈에 내려다 볼 수 있는 경치 좋은 공원입니다. 부산역에서 333번 타면...  5.0
# 12  부산하면 민주화 성지잖아요. 산책하면서 역사도 알아가니 좋았습니다. 공기도 좋아서 ...  4.0
# 13  밤에 오는 것을 추천. 화려하진 않지만 부산의 야경을 다각도로 볼 수 있음. 사람이...  4.0
# 14  한국 전쟁의 세부 사진이 많이 있습니다. 당신은 기념비에 계단을 오를 수있다, 또는...  5.0
# 15  파크 호텔은 쇼핑 지역 근처에 위치한 민주주의 부산 남포. 이는 거리에서 벗어난 사...  4.0
