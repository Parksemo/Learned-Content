# %% [markdown]
# # API 접속

# %%
from pykiwoom.kiwoom import *
import time
import pandas as pd

# %%
#로그인
kiwoom = Kiwoom()
print("로그인중")
kiwoom.CommConnect(block=True)
print(("로그인 완료"))
# Out:
# 로그인중
# 로그인 완료

# %%
#연결
state = kiwoom.GetConnectState()
if state == 0:
    print('연결되지않음')
elif state == 1:
    print("연결됨")
# Out:
# 연결됨

# %%
#로그인정보
account_num = kiwoom.GetLoginInfo("ACCOUNT_CNT")        # 전체 계좌수
accounts = kiwoom.GetLoginInfo("ACCNO")                 # 전체 계좌 리스트
user_id = kiwoom.GetLoginInfo("USER_ID")                # 사용자 ID
user_name = kiwoom.GetLoginInfo("USER_NAME")            # 사용자명
keyboard = kiwoom.GetLoginInfo("KEY_BSECGB")            # 키보드보안 해지여부
firewall = kiwoom.GetLoginInfo("FIREW_SECGB")           # 방화벽 설정 여부
# print(account_num)
# print(accounts)
# print(user_id)
# print(user_name)
# print(keyboard)
# print(firewall)

# %% [markdown]
# # 일봉데이터 수집

# %%
df_multi = kiwoom.block_request('opt10081',
                                 종목코드 = '035720',
                                 기준일자 = '20220706',
                                 수정주가구분 = 1,
                                 output = '주식일봉차트조회',
                                 next=0
                                 )
df_multi
# Out:
# CommRqData opt10081 opt10081 0 0101
#        종목코드    현재가      거래량    거래대금        일자     시가     고가     저가 수정주가구분  \
# 0    035720  73500  2724220  201130  20220706  71300  75000  71200
# 1            72000  2125688  151212  20220705  68700  72500  68300
# 2            68100  1019171   69141  20220704  67300  69000  66200
# 3            67300  1817276  123969  20220701  70000  70300  66600
# 4            69900  1339031   94024  20220630  70400  71100  69900
# ..      ...    ...      ...     ...       ...    ...    ...    ...    ...
# 595          33918  1869502   63204  20200210  33617  34019  33316
# 596          33617  2601395   87779  20200207  33517  34219  33316
# 597          33316  2750593   91982  20200206  33216  33718  32814
# 598          32714  2276801   74890  20200205  33417  33517  32413
# 599          33015  1966981   64589  20200204  32413  33216  32212
#
#     수정비율 대업종구분 소업종구분 종목정보 수정주가이벤트 전일종가
# 0
# 1
# 2
# 3
# 4
# ..   ...   ...   ...  ...     ...  ...
# 595
# 596
# 597
# 598
# 599
#
# [600 rows x 15 columns]

# %%
df_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   종목코드     600 non-null    object
#  1   현재가      600 non-null    object
#  2   거래량      600 non-null    object
#  3   거래대금     600 non-null    object
#  4   일자       600 non-null    object
#  5   시가       600 non-null    object
#  6   고가       600 non-null    object
#  7   저가       600 non-null    object
#  8   수정주가구분   600 non-null    object
#  9   수정비율     600 non-null    object
#  10  대업종구분    600 non-null    object
#  11  소업종구분    600 non-null    object
#  12  종목정보     600 non-null    object
#  13  수정주가이벤트  600 non-null    object
#  14  전일종가     600 non-null    object
# dtypes: object(15)
# memory usage: 35.2+ KB

# %% [markdown]
# # 필요한 데이터만 가져오기

# %%
df = pd.DataFrame()
df['일자'] = pd.to_datetime(df_multi['일자'])
df['종가'] = df_multi['현재가'].astype(int)
df['거래량'] = df_multi['거래량'].astype(int)
df
# Out:
#             일자     종가      거래량
# 0   2022-07-06  73500  2724220
# 1   2022-07-05  72000  2125688
# 2   2022-07-04  68100  1019171
# 3   2022-07-01  67300  1817276
# 4   2022-06-30  69900  1339031
# ..         ...    ...      ...
# 595 2020-02-10  33918  1869502
# 596 2020-02-07  33617  2601395
# 597 2020-02-06  33316  2750593
# 598 2020-02-05  32714  2276801
# 599 2020-02-04  33015  1966981
#
# [600 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      600 non-null    datetime64[ns]
#  1   종가      600 non-null    int32
#  2   거래량     600 non-null    int32
# dtypes: datetime64[ns](1), int32(2)
# memory usage: 9.4 KB

# %% [markdown]
# # 등락률 계산

# %%
#등락률 계산 : 일 등락률 = (오늘종가 – 어제종가) / 어제종가 * 100 => 평균
등락률 = []
for i in range(len(df['종가'])):
    if i == len(df['종가'])-1:
        break
    else:    
        등락률.append((df['종가'][i]-df['종가'][i+1])/df['종가'][i+1]*100)
등락률.append(0)

# %%
df['등락률']=등락률

# %%
df
# Out:
#             일자     종가      거래량       등락률
# 0   2022-07-06  73500  2724220  2.083333
# 1   2022-07-05  72000  2125688  5.726872
# 2   2022-07-04  68100  1019171  1.188707
# 3   2022-07-01  67300  1817276 -3.719599
# 4   2022-06-30  69900  1339031 -1.271186
# ..         ...    ...      ...       ...
# 595 2020-02-10  33918  1869502  0.895380
# 596 2020-02-07  33617  2601395  0.903470
# 597 2020-02-06  33316  2750593  1.840191
# 598 2020-02-05  32714  2276801 -0.911707
# 599 2020-02-04  33015  1966981  0.000000
#
# [600 rows x 4 columns]

# %% [markdown]
# # 거래변동량 계산

# %%
#거래변동량 계산 : 오늘거래량 - 어제거래량
거래변동량 = []
for i in range(len(df['거래량'])):
    if i == len(df['거래량'])-1:
        break
    else:    
        거래변동량.append(abs((df['거래량'][i]-df['거래량'][i+1])))
거래변동량.append(0)

# %%
df['거래변동량']=거래변동량

# %%
df
# Out:
#             일자     종가      거래량       등락률    거래변동량
# 0   2022-07-06  73500  2724220  2.083333   598532
# 1   2022-07-05  72000  2125688  5.726872  1106517
# 2   2022-07-04  68100  1019171  1.188707   798105
# 3   2022-07-01  67300  1817276 -3.719599   478245
# 4   2022-06-30  69900  1339031 -1.271186   153560
# ..         ...    ...      ...       ...      ...
# 595 2020-02-10  33918  1869502  0.895380   731893
# 596 2020-02-07  33617  2601395  0.903470   149198
# 597 2020-02-06  33316  2750593  1.840191   473792
# 598 2020-02-05  32714  2276801 -0.911707   309820
# 599 2020-02-04  33015  1966981  0.000000        0
#
# [600 rows x 5 columns]

# %% [markdown]
# # 종가 data 정규화

# %%
#종가 data 정규화 MinMaxScaler()
from sklearn.preprocessing import MinMaxScaler

# %%
df_종가 = pd.DataFrame()
df_종가['종가'] = df['종가']

# %%
scaler = MinMaxScaler()
scaler.fit(df_종가)
df_scaled = scaler.transform(df_종가)

# %%
df_종가_scaled = pd.DataFrame(data = df_scaled)

# %%
df_종가_scaled.min()
# Out:
# 0    0.0
# dtype: float64

# %%
df_종가_scaled.max()
# Out:
# 0    1.0
# dtype: float64

# %%
df['정규화_종가']=df_종가_scaled
df
# Out:
#             일자     종가      거래량       등락률    거래변동량    정규화_종가
# 0   2022-07-06  73500  2724220  2.083333   598532  0.326817
# 1   2022-07-05  72000  2125688  5.726872  1106517  0.316298
# 2   2022-07-04  68100  1019171  1.188707   798105  0.288950
# 3   2022-07-01  67300  1817276 -3.719599   478245  0.283340
# 4   2022-06-30  69900  1339031 -1.271186   153560  0.301572
# ..         ...    ...      ...       ...      ...       ...
# 595 2020-02-10  33918  1869502  0.895380   731893  0.049255
# 596 2020-02-07  33617  2601395  0.903470   149198  0.047144
# 597 2020-02-06  33316  2750593  1.840191   473792  0.045033
# 598 2020-02-05  32714  2276801 -0.911707   309820  0.040812
# 599 2020-02-04  33015  1966981  0.000000        0  0.042922
#
# [600 rows x 6 columns]

# %%
df_multi = kiwoom.block_request('opt10081',
                                 종목코드 = '035720',
                                 기준일자 = '20220706',
                                 수정주가구분 = 1,
                                 output = '주식일봉차트조회',
                                 next=0
                                 )
df_multi.head(1)
# Out:
# CommRqData opt10081 opt10081 0 0101
#      종목코드    현재가      거래량    거래대금        일자     시가     고가     저가 수정주가구분 수정비율  \
# 0  035720  73500  2724220  201130  20220706  71300  75000  71200
#
#   대업종구분 소업종구분 종목정보 수정주가이벤트 전일종가
# 0
