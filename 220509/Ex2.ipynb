# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
#이전에는 문서로 받았으며, 이는 문장으로 받음
all_data = DoublespaceLineCorpus('data1.txt',iter_sent=True) #iter_sent=True 문장단위로 끊어줌
len(all_data)
# Out:
# 223357

# %%
all_data

# %%
n=0
for i in all_data:
    print(i)
    n+=1
    if n==4:
        break
# Out:
# 19
# 1990
# 52 1 22
# 오패산터널 총격전 용의자 검거 서울 연합뉴스 경찰 관계자들이 19일 오후 서울 강북구 오패산 터널 인근에서 사제 총기를 발사해 경찰을 살해한 용의자 성모씨를 검거하고 있다 성씨는 검거 당시 서바이벌 게임에서 쓰는 방탄조끼에 헬멧까지 착용한 상태였다 독자제공 영상 캡처 연합뉴스

# %%
m = WordExtractor()
m.train(all_data)
# Out:
# training was done. used memory 0.770 Gbse memory 0.836 Gb

# %%
m.extract()
# Out:
# all cohesion probabilities was computed. # words = 223348
# all branching entropies was computed # words = 360721
# all accessor variety was computed # words = 360721
# {'벗': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=1.9352037859131317, right_branching_entropy=1.3504896767689845, left_accessor_variety=22, right_accessor_variety=13, leftside_frequency=768, rightside_frequency=0),
#  '폰': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=1.9479873727765824, right_branching_entropy=4.207964652286875, left_accessor_variety=26, right_accessor_variety=113, leftside_frequency=57, rightside_frequency=1094),
#  '옴': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=2.293464514332349, right_branching_entropy=1.3888205684879371, left_accessor_variety=17, right_accessor_variety=5, leftside_frequency=142, rightside_frequency=0),
# ...

# %%
t1 = '영화가 너무 웃겨'
t2 = '영화가 너무 웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'
t3 = '영화가 너무 웃겨 ㅋㅋ'
t4 = '영화가 너무 웃겨 ㅋㅋㅋ'

# %%
from soynlp.normalizer import *

# %%
emoticon_normalize(t1)
# Out:
# '영화가 너무 웃겨'

# %%
emoticon_normalize(t2)
# Out:
# '영화가 너무 웃겨 ㅋㅋ'

# %%
emoticon_normalize(t2,num_repeats=3)
# Out:
# '영화가 너무 웃겨 ㅋㅋㅋ'

# %%
emoticon_normalize(t2,num_repeats=1)
# Out:
# '영화가 너무 웃겨 ㅋ'

# %%
t_e="후후후후후후훗"
emoticon_normalize(t_e)
# Out:
# '후후훗'

# %%
emoticon_normalize('1231231231111111112222222223333333567567')
# Out:
# '123123123112233567567'
